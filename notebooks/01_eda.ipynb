# %% [markdown]
# # 01. 탐색적 데이터 분석 (EDA)
#
# **목표:** 데이터셋의 구조와 특성을 탐색하고, 모델 학습 전 인사이트를 도출합니다.
#
# | 항목 | 내용 |
# |------|------|
# | 데이터셋 | Social Media Impact on Teen Mental Health |
# | 출처 | Kaggle (algozee/teenager-menthal-healy) |
# | 라이선스 | Apache 2.0 |

# %%
import sys
sys.path.insert(0, '../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from teen_mind.data.loader import load_raw_data, validate_raw_data

pd.set_option('display.max_columns', None)
print('라이브러리 로드 완료')
# Out:
# 라이브러리 로드 완료

# %% [markdown]
# ## 1. 데이터 로드 및 기본 검증

# %%
# data/raw/ 폴더에 CSV 파일이 있어야 합니다
# kaggle datasets download -d algozee/teenager-menthal-healy
# unzip *.zip -d ../data/raw/

import os
raw_files = [f for f in os.listdir('../data/raw') if f.endswith('.csv')]
print('발견된 파일:', raw_files)

df = load_raw_data(raw_files[0])
print(f'\n데이터 크기: {df.shape}')

df.head()
# Out:
# 발견된 파일: ['Teen_Mental_Health_Dataset.csv']
# [로드 완료] Teen_Mental_Health_Dataset.csv → 1200행 × 13열
#
# 데이터 크기: (1200, 13)
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# 0                      low             2              2                1
# 1                     high             8              1               10
# 2                     high             2              4                2
# 3                   medium             1              7                9
# 4                   medium             3              5                2
#
#    depression_label
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
# 데이터 품질 검증
validation = validate_raw_data(df)
print('검증 결과:')
for k, v in validation.items():
    print(f'  {k}: {v}')
# Out:
# ==================================================
# 데이터 검증 결과
# ==================================================
# 행 수: 1200
# 열 수: 13
# 전체 결측 비율: 0.00%
# 클래스 분포: {0: 0.9741666666666666, 1: 0.025833333333333333}
#
# ⚠️  발견된 문제:
#   - 클래스 불균형이 심합니다. 최소 클래스 비율: 2.6%
# ==================================================
#
# 검증 결과:
#   row_count: 1200
#   column_count: 13
#   missing_ratio: {'age': 0.0, 'gender': 0.0, 'daily_social_media_hours': 0.0, 'platform_usage': 0.0, 'sleep_hours': 0.0, 'screen_time_before_sleep': 0.0, 'academic_performance': 0.0, 'physical_activity': 0.0, 'social_interaction_level': 0.0, 'stress_level': 0.0, 'anxiety_level': 0.0, 'addiction_level': 0.0, 'depression_label': 0.0}
#   dtype_summary: {'age': 'int64', 'gender': 'object', 'daily_social_media_hours': 'float64', 'platform_usage': 'object', 'sleep_hours': 'float64', 'screen_time_before_sleep': 'float64', 'academic_performance': 'float64', 'physical_activity': 'float64', 'social_interaction_level': 'object', 'stress_level': 'int64', 'anxiety_level': 'int64', 'addiction_level': 'int64', 'depression_label': 'int64'}
#   issues: ['클래스 불균형이 심합니다. 최소 클래스 비율: 2.6%']
#   class_distribution: {0: 0.9741666666666666, 1: 0.025833333333333333}
#   is_valid: False

# %%
print('데이터 타입:')
print(df.dtypes)
print('\n결측치 현황:')
print(df.isnull().sum())
print('\n기본 통계:')
df.describe()
# Out:
# 데이터 타입:
# age                           int64
# gender                       object
# daily_social_media_hours    float64
# platform_usage               object
# sleep_hours                 float64
# screen_time_before_sleep    float64
# academic_performance        float64
# physical_activity           float64
# social_interaction_level     object
# stress_level                  int64
# anxiety_level                 int64
# addiction_level               int64
# depression_label              int64
# dtype: object
#
# 결측치 현황:
# age                         0
# gender                      0
# daily_social_media_hours    0
# platform_usage              0
# sleep_hours                 0
# screen_time_before_sleep    0
# academic_performance        0
# physical_activity           0
# social_interaction_level    0
# stress_level                0
# anxiety_level               0
# addiction_level             0
# depression_label            0
# dtype: int64
#
# 기본 통계:
#                age  daily_social_media_hours  sleep_hours  \
# count  1200.000000               1200.000000  1200.000000
# mean     15.928333                  4.536667     6.449417
# std       2.021947                  2.029599     1.442677
# min      13.000000                  1.000000     4.000000
# 25%      14.000000                  2.800000     5.200000
# 50%      16.000000                  4.500000     6.500000
# 75%      18.000000                  6.300000     7.600000
# max      19.000000                  8.000000     9.000000
#
#        screen_time_before_sleep  academic_performance  physical_activity  \
# count               1200.000000           1200.000000        1200.000000
# mean                   1.740333              2.990383           1.014500
# std                    0.716660              0.576758           0.582185
# min                    0.500000              2.000000           0.000000
# 25%                    1.100000              2.500000           0.500000
# 50%                    1.800000              2.990000           1.000000
# 75%                    2.400000              3.480000           1.500000
# max                    3.000000              4.000000           2.000000
#
#        stress_level  anxiety_level  addiction_level  depression_label
# count   1200.000000    1200.000000      1200.000000       1200.000000
# mean       5.445833       5.636667         5.565000          0.025833
# std        2.903290       2.859453         2.830627          0.158704
# min        1.000000       1.000000         1.000000          0.000000
# 25%        3.000000       3.000000         3.000000          0.000000
# 50%        5.000000       6.000000         6.000000          0.000000
# 75%        8.000000       8.000000         8.000000          0.000000
# max       10.000000      10.000000        10.000000          1.000000

# %% [markdown]
# ## 2. 타겟 변수 분포

# %%
from teen_mind.utils.visualization import plot_class_distribution

fig = plot_class_distribution(df['depression_label'])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/projects/kaggle-ml/teen-mind-ai/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mental_health_risk'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 from teen_mind.utils.visualization import plot_class_distribution
# ----> 3 fig = plot_class_distribution(df['mental_health_risk'])
#       4 fig.show()
#
# File ~/Desktop/projects/kaggle-ml/teen-mind-ai/.venv/lib/python3.10/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/Desktop/projects/kaggle-ml/teen-mind-ai/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'mental_health_risk'

# %% [markdown]
# ## 3. 상관관계 분석

# %%
from teen_mind.utils.visualization import plot_correlation_heatmap

fig = plot_correlation_heatmap(df)
plt.show()

# %% [markdown]
# ## 4. 소셜미디어 사용 vs 우울점수

# %%
from teen_mind.utils.visualization import plot_social_media_vs_mental_health

fig = plot_social_media_vs_mental_health(df)
fig.show()

# %% [markdown]
# ## 5. 주요 인사이트 정리
#
# > **여기에 분석 결과를 적어보세요:**
# > - 소셜미디어 사용 시간과 우울 점수 간의 관계:
# > - 수면 시간과 불안 점수 간의 관계:
# > - 클래스 불균형 여부:
# > - 특이 이상치 패턴:
